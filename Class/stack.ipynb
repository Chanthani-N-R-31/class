# %%
''''Alogorithem number : 2
    Alogorithem name: "Queue"
    script author : Chanthani N R'''
    
#create a queue using  class
class Queue(object):
    #assign a variablr
    Queue_IT=[]
    '''define a function to add elements in stack using append operatiom'''
    def insert(self,info:object):
        self.Queue_IT.append(info)
        '''define a function to delete the first elememt in the queue using pop function'''
    def delet(self):
        self.Queue_IT.pop(0)
        '''define a functuin to dispaly the elements in the queue using for loop to iiterate the value and display each element'''
    def dis(self):
        for info in self.Queue_IT:
            print(info)
def QUEUE():
    a=Queue()
    #add the values using the functio n called inside the queue
    a.insert(10)
    a.insert(22)
    a.insert(11)
    a.insert(44)
    a.insert(56)
    print("Queue before deleting")
    #display elements in the queue
    a.dis()
    #delete the first element in the queue
    a.delet()
    #print and dispaly the elemets after deleting the first element
    print("Queue after delteing")
    a.dis()
QUEUE()
    


#create a class as stack to sytack the elements
class Stack():
#asssign a varauble
    stack_it=[]
#intitiate the value using __init__ class
    def insert(self,info):
    #use appenf  to add the values in to the stack
        self.stack_it.append(info)
    def delete(self):
    #use pop to delte the last elemrnt
        self.stack_it.pop()
    def show(self):
    #use for loop to iterate and show values
        for info in self.stack_it:
            print(info)
    #creating a object 
def STACK():
    a=Stack()
    #calling method with the help of object
    a.insert(2)
    a.insert(32)
    a.insert(45)
    a.insert(15)
    a.insert(9)
    a.insert(23)
    print("stack before deleting")
    #display the  stack elements added
    a.show()
    #to pop the  last elemnet call the function 
    a.delete()
    print("stack after deleting")
    #dispaly the final elements in the stack after deleting
    a.show()
STACK()
# Out:
# stack before deleting
# 2
# 32
# 45
# 15
# 9
# 23
# stack after deleting
# 2
# 32
# 45
# 15
# 9
